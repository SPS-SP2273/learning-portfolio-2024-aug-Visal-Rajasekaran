# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os
import glob
import shutil

# %%
#Changing the directory to make file paths shorter down stream
os.chdir('C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder\\Data')

# %%
#Checking whether directory changed successfully
os.getcwd()
# Out:
# 'C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder\\Data'

# %%
month_dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
#Note to self. This style of renaming is not advisable. Acidentally re-running this piece of code may mess up the saved files although I think
#it probably will not be an issue since the part of accessing the dictionary for a value should present an error. A modified version to check

file_names = glob.glob('*.txt')
months = [path_string.split(sep='-') for path_string in file_names] #Extracting the months part from the names of each file. The os.path.splitext is actually unncessasary

for count,old_file_name in enumerate(file_names):
    os.rename(old_file_name, (month_dict[months[count][0]]+'-'+months[count][1]).replace('_','-'))
    #print(old_file_name, '----->', (month_dict[months[count][0]]+'-'+months[count][1]).replace('_','-')) #Statement to verify renaming

# %%
#Checking whether filenames were renamed successfully
glob.glob('*.txt')
# Out:
# ['01-01-manila.txt',
#  '01-01-osaka.txt',
#  '01-02-cairo.txt',
#  '01-02-karachi.txt',
#  '01-02-manila.txt',
#  '01-03-cairo.txt',
#  '01-03-jakarta.txt',
#  '01-03-karachi.txt',
#  '01-03-shanghai.txt',
#  '01-04-cairo.txt',
#  '01-04-jakarta.txt',
#  '01-04-karachi.txt',
#  '01-04-manila.txt',
#  '01-05-cairo.txt',
#  '01-05-melbourne.txt',
#  '01-05-osaka.txt',
#  '01-06-jakarta.txt',
#  '01-06-karachi.txt',
#  '01-06-melbourne.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-08-manila.txt',
#  '01-08-osaka.txt',
#  '01-08-tokyo.txt',
#  '01-09-cairo.txt',
#  '01-09-karachi.txt',
#  '01-09-manila.txt',
#  '01-09-melbourne.txt',
#  '01-10-jakarta.txt',
#  '01-10-karachi.txt',
#  '01-10-shanghai.txt',
#  '01-11-cairo.txt',
#  '01-11-manila.txt',
#  '01-11-melbourne.txt',
#  '01-12-cairo.txt',
#  '01-12-jakarta.txt',
#  '01-12-karachi.txt',
#  '01-12-melbourne.txt',
#  '01-12-osaka.txt',
#  '01-12-tokyo.txt',
#  '01-13-cairo.txt',
#  '01-13-jakarta.txt',
# ...

# %%
#Preferred method for file renaming using function
def rename_my_file(old_file_name):
    
    split_file_name = old_file_name.split(sep='-')
    
    if len(split_file_name) == 3 and split_file_name[0].isnumeric() : #Rough check of whether file has already been renamed
        return old_file_name
        
    
    month = split_file_name[0]
    date, country_and_ext = split_file_name[1].split(sep='_')
    new_file_name = month_dict[month] + '-' + date + '-' + country_and_ext
    return new_file_name

# %%
file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for old_file_name in file_list:
    #rename_my_file(old_file_name)
    print(f"{old_file_name}----->{rename_my_file(old_file_name)}")
# Out:
# oct-08_singapore.txt----->10-08-singapore.txt
# jul-10_cairo.txt----->07-10-cairo.txt
# may-15_dhaka.txt----->05-15-dhaka.txt
# may-13_cairo.txt----->05-13-cairo.txt
# oct-21_cairo.txt----->10-21-cairo.txt
# jan-10_singapore.txt----->01-10-singapore.txt
# jun-20_tokyo.txt----->06-20-tokyo.txt
# aug-06_jakarta.txt----->08-06-jakarta.txt
# dec-21_karachi.txt----->12-21-karachi.txt
# jan-01_tokyo.txt----->01-01-tokyo.txt

# %%
os.chdir('C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder\\Data2')
os.getcwd()
# Out:
# 'C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder\\Data2'

# %%
glob.glob('*') #To view all the files before renaming

# %%
os.path.exists('apr-01_melbourne.pdf') #Checking whether os.path.exists is working properly
# Out:
# True

# %%
#Note to self. This below is the recommended style of renaming.

file_names = glob.glob('*.txt')

for old_file_name in file_names:
    try:
        new_file_name = rename_my_file(old_file_name)
        if not os.path.exists(new_file_name):     #Seems redundant but may save some time. Skips file if it is already renamed
            os.rename(old_file_name, new_file_name)
    except Exception as err:
        print("Error ",err)

# %%
glob.glob('*')
# Out:
# ['01-01-manila.txt',
#  '01-01-osaka.txt',
#  '01-02-cairo.txt',
#  '01-02-karachi.txt',
#  '01-02-manila.txt',
#  '01-03-cairo.txt',
#  '01-03-jakarta.txt',
#  '01-03-karachi.txt',
#  '01-03-shanghai.txt',
#  '01-04-cairo.txt',
#  '01-04-jakarta.txt',
#  '01-04-karachi.txt',
#  '01-04-manila.txt',
#  '01-05-cairo.txt',
#  '01-05-melbourne.txt',
#  '01-05-osaka.txt',
#  '01-06-jakarta.txt',
#  '01-06-karachi.txt',
#  '01-06-melbourne.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-08-manila.txt',
#  '01-08-osaka.txt',
#  '01-08-tokyo.txt',
#  '01-09-cairo.txt',
#  '01-09-karachi.txt',
#  '01-09-manila.txt',
#  '01-09-melbourne.txt',
#  '01-10-jakarta.txt',
#  '01-10-karachi.txt',
#  '01-10-shanghai.txt',
#  '01-11-cairo.txt',
#  '01-11-manila.txt',
#  '01-11-melbourne.txt',
#  '01-12-cairo.txt',
#  '01-12-jakarta.txt',
#  '01-12-karachi.txt',
#  '01-12-melbourne.txt',
#  '01-12-osaka.txt',
#  '01-12-tokyo.txt',
#  '01-13-cairo.txt',
#  '01-13-jakarta.txt',
# ...

# %%
#Changing path to where I want the folders to be
os.chdir('C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder')
os.getcwd()
# Out:
# 'C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder'

# %%
#Creating folders for each country

new_file_names = glob.glob('*')

city_names = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city_name in city_names:
    os.mkdir(city_name)
    print(f'Created {city_name} {os.path.exists(city_name)}')
# Out:
# Created Cairo True
# Created Dhaka True
# Created Jakarta True
# Created Karachi True
# Created Manila True
# Created Melbourne True
# Created Osaka True
# Created Shanghai True
# Created Singapore True
# Created Tokyo True

# %%
#Checking funcionality of extracting filenames with cairo
glob.glob('Data2\\*cairo.txt')
# Out:
# ['Data2\\01-02-cairo.txt',
#  'Data2\\01-03-cairo.txt',
#  'Data2\\01-04-cairo.txt',
#  'Data2\\01-05-cairo.txt',
#  'Data2\\01-07-cairo.txt',
#  'Data2\\01-08-cairo.txt',
#  'Data2\\01-09-cairo.txt',
#  'Data2\\01-11-cairo.txt',
#  'Data2\\01-12-cairo.txt',
#  'Data2\\01-13-cairo.txt',
#  'Data2\\01-15-cairo.txt',
#  'Data2\\01-16-cairo.txt',
#  'Data2\\01-19-cairo.txt',
#  'Data2\\01-20-cairo.txt',
#  'Data2\\01-21-cairo.txt',
#  'Data2\\01-23-cairo.txt',
#  'Data2\\01-27-cairo.txt',
#  'Data2\\01-30-cairo.txt',
#  'Data2\\02-10-cairo.txt',
#  'Data2\\02-17-cairo.txt',
#  'Data2\\02-20-cairo.txt',
#  'Data2\\02-22-cairo.txt',
#  'Data2\\02-25-cairo.txt',
#  'Data2\\02-26-cairo.txt',
#  'Data2\\03-05-cairo.txt',
#  'Data2\\03-06-cairo.txt',
#  'Data2\\03-12-cairo.txt',
#  'Data2\\03-14-cairo.txt',
#  'Data2\\03-19-cairo.txt',
#  'Data2\\03-24-cairo.txt',
#  'Data2\\04-02-cairo.txt',
#  'Data2\\04-06-cairo.txt',
#  'Data2\\04-07-cairo.txt',
#  'Data2\\04-10-cairo.txt',
# ...

# %%
cairo_files = glob.glob('Data2\\*cairo.txt')
destination_folder_cairo = os.path.join('C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder','Cairo')
for file_cairo in cairo_files:
    shutil.copy(file_cairo, destination_folder_cairo)
    print(f'Copied {file_cairo} successfully')
# Out:
# Copied Data2\01-02-cairo.txt successfully
# Copied Data2\01-03-cairo.txt successfully
# Copied Data2\01-04-cairo.txt successfully
# Copied Data2\01-05-cairo.txt successfully
# Copied Data2\01-07-cairo.txt successfully
# Copied Data2\01-08-cairo.txt successfully
# Copied Data2\01-09-cairo.txt successfully
# Copied Data2\01-11-cairo.txt successfully
# Copied Data2\01-12-cairo.txt successfully
# Copied Data2\01-13-cairo.txt successfully
# Copied Data2\01-15-cairo.txt successfully
# Copied Data2\01-16-cairo.txt successfully
# Copied Data2\01-19-cairo.txt successfully
# Copied Data2\01-20-cairo.txt successfully
# Copied Data2\01-21-cairo.txt successfully
# Copied Data2\01-23-cairo.txt successfully
# Copied Data2\01-27-cairo.txt successfully
# Copied Data2\01-30-cairo.txt successfully
# Copied Data2\02-10-cairo.txt successfully
# Copied Data2\02-17-cairo.txt successfully
# Copied Data2\02-20-cairo.txt successfully
# Copied Data2\02-22-cairo.txt successfully
# ...

# %%
for city in city_names:
    city_files = glob.glob('Data2\\*'+city.lower()+'.txt')
    destination_folder_city = os.path.join('C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder',city)
    for file_city in city_files:
        shutil.copy(file_city, destination_folder_city)
        print(f'Copied {file_city} successfully')
# Out:
# Copied Data2\01-02-cairo.txt successfully
# Copied Data2\01-03-cairo.txt successfully
# Copied Data2\01-04-cairo.txt successfully
# Copied Data2\01-05-cairo.txt successfully
# Copied Data2\01-07-cairo.txt successfully
# Copied Data2\01-08-cairo.txt successfully
# Copied Data2\01-09-cairo.txt successfully
# Copied Data2\01-11-cairo.txt successfully
# Copied Data2\01-12-cairo.txt successfully
# Copied Data2\01-13-cairo.txt successfully
# Copied Data2\01-15-cairo.txt successfully
# Copied Data2\01-16-cairo.txt successfully
# Copied Data2\01-19-cairo.txt successfully
# Copied Data2\01-20-cairo.txt successfully
# Copied Data2\01-21-cairo.txt successfully
# Copied Data2\01-23-cairo.txt successfully
# Copied Data2\01-27-cairo.txt successfully
# Copied Data2\01-30-cairo.txt successfully
# Copied Data2\02-10-cairo.txt successfully
# Copied Data2\02-17-cairo.txt successfully
# Copied Data2\02-20-cairo.txt successfully
# Copied Data2\02-22-cairo.txt successfully
# ...

# %%
#Checking that the folders are succesffuly created 
os.chdir('C:\\Users\\rsvis\\Documents\\NUS\\Y1S1\\SP2273\\learning-portfolio-2024-aug-Visal-Rajasekaran\\6.2_files,_folders_&_os__exercises\\DataFolder')
os.getcwd()
glob.glob('*/*')
# Out:
# ['Cairo\\01-02-cairo.txt',
#  'Cairo\\01-03-cairo.txt',
#  'Cairo\\01-04-cairo.txt',
#  'Cairo\\01-05-cairo.txt',
#  'Cairo\\01-07-cairo.txt',
#  'Cairo\\01-08-cairo.txt',
#  'Cairo\\01-09-cairo.txt',
#  'Cairo\\01-11-cairo.txt',
#  'Cairo\\01-12-cairo.txt',
#  'Cairo\\01-13-cairo.txt',
#  'Cairo\\01-15-cairo.txt',
#  'Cairo\\01-16-cairo.txt',
#  'Cairo\\01-19-cairo.txt',
#  'Cairo\\01-20-cairo.txt',
#  'Cairo\\01-21-cairo.txt',
#  'Cairo\\01-23-cairo.txt',
#  'Cairo\\01-27-cairo.txt',
#  'Cairo\\01-30-cairo.txt',
#  'Cairo\\02-10-cairo.txt',
#  'Cairo\\02-17-cairo.txt',
#  'Cairo\\02-20-cairo.txt',
#  'Cairo\\02-22-cairo.txt',
#  'Cairo\\02-25-cairo.txt',
#  'Cairo\\02-26-cairo.txt',
#  'Cairo\\03-05-cairo.txt',
#  'Cairo\\03-06-cairo.txt',
#  'Cairo\\03-12-cairo.txt',
#  'Cairo\\03-14-cairo.txt',
#  'Cairo\\03-19-cairo.txt',
#  'Cairo\\03-24-cairo.txt',
#  'Cairo\\04-02-cairo.txt',
#  'Cairo\\04-06-cairo.txt',
#  'Cairo\\04-07-cairo.txt',
#  'Cairo\\04-10-cairo.txt',
# ...
