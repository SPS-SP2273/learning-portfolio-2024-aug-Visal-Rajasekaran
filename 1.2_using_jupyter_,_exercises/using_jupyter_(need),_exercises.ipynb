# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need), Exercises</span></div>

# %% [markdown]
# ## 1 Quadratic Equations

# %% [markdown]
# ### Introduction
#
# ![image.png](attachment:image.png)
# (Image from the [Wikipedia page on Quadratic equations)](https://en.wikipedia.org/wiki/Quadratic_equation)
#
# The general form of a quadratic equation is: $$ax^2 + bx + c = 0$$
#
#
# ### Solutions
# Provided $a\neq 0$
# , we can use an elementary algebraic method called [completing the square](https://en.wikipedia.org/wiki/Completing_the_square) to show that a quadratic equation has the following solution:
# $$x = \frac{-b\pm\sqrt{b^2 - 4ac}}{2a}$$
#
#
# ### Discriminant
# The quantity $b^2 - 4ac$ is called the discriminant of the equation and decides the nature of its solutions. The table below shows the various possibilities.
#
# | Discriminant | Roots |
# |:------:|:------:|
# | $$\Delta = b^2 - 4ac = 0$$ | A single solution of $-b/(2a)$ |
# | $$\Delta = b^2 - 4ac > 0$$ | 2 real distinct solutions |
# | $$\Delta = b^2 - 4ac < 0$$ | No real solutions; Both are complex |

# %% [markdown]
# ### Solutions

# %% [markdown]
# What is a Git repository?
# Git keeps tracks of changes in the files in our repository.
# What is a commit?
# A commit is the selection and confirmation of the detected changes in the file.
# What is a push?
# The committed changes are uploaded to the Git repository or cloud.
# What is a pull?
# Changes made to the files in the cloud by other members or self is downloaded into the local workspace.
# What is the difference between GitHub and GitHub Desktop?
# GitHub is the cloud save of the files while GitHub Desktop tracks and manages changes within a clone of the repository in a local
# host environment and allows for effective collaboration.

# %% [markdown]
# ### Discriminant

# %% [markdown]
# $$
# \mu = \frac{1}{n} \sum_{i=1}^{n}x_i\tag{1}
# $$$$
# \sigma= \sqrt{\frac{1}{n}\sum_{i=1}^{n}(x_i - \mu)^2)}\tag{2}
# $$$$
# r = \frac{\sum_{i=1}^{n}(x_i - \mu_X)(y_i - \mu_Y)}{\sqrt{\sum_{i=1}^{n}(x_i - \mu_X)^2\sum_{i=1}^{n}(y_i - \mu_Y)^2}}\tag{3}
# $$
# Double backslash not recognized as newline in notebook version 7

# %% [markdown]
# $\mu = \frac{1}{n} \sum_{i=1}^{n}x_i\tag{1}$
# $\sigma= \sqrt{\frac{1}{n}\sum_{i=1}^{n}(x_i - \mu)^2)}\tag{2}$
# $$r = \frac{\sum_{i=1}^{n}(x_i - \mu_X)(y_i - \mu_Y)}{\sqrt{\sum_{i=1}^{n}(x_i - \mu_X)^2\sum_{i=1}^{n}(y_i - \mu_Y)^2}}\tag{3}$$
# Double space at end of line with seperate codelines works but not within code block

# %% [markdown]
# $$
# \mu = \frac{1}{n} \sum_{i=1}^{n}x_i\tag{1}
# \mu = \frac{1}{n} \sum_{i=1}^{n}x_i\tag{1}
# $$
# Cannot have multiple equations in 1 code block
